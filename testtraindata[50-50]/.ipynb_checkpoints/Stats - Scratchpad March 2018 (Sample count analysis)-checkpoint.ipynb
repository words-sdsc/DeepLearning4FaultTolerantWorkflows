# %%
import pickle

# %%
import pandas as pd

# %%
df = pd.read_pickle('mega_allHBLI_wide_scaled.pickle')

# %%
df.shape
# Out:
# (17572524, 9)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

sample_counts = pd.value_counts(df['JobID'].values, sort=True)

# %%
import matplotlib
font = {'family' : 'Arial',
        'size'   : 22}

matplotlib.rc('font', **font)

# %%
plt.figure(figsize=(20,10))
plt.hist(sample_counts[sample_counts<50].values, bins = 100)
plt.show()

# %%
df.shape
# Out:
# (17572524, 9)
